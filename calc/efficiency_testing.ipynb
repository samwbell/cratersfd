# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec
from matplotlib.ticker import ScalarFormatter
import math
from scipy.stats.mstats import gmean
from scipy.stats import gamma, poisson, linregress, beta, norm, lognorm
from scipy import optimize
from scipy import interpolate
import time
import random
import pickle as pkl
from cratersfd import *
# %matplotlib inline

# %%
dmin = 1.0
dmax = 1E4
area = 1000

for N in [100, 300, 1000, 3000, 5000, 7000, 10000, 30000, 100000]:
    ds = synth_fixed_N(
        N=N, dmin=dmin, pf=npf_new_loglog, n_steps=1
    )[0][0]
    full_time0()
    _, _, _ = calc_sash(ds, area, n_alpha_points=1000, n_points=10000)
    full_runtime('N=' + str(N))
# Out:
# N=100: 0.40522 seconds
# N=300: 0.4109 seconds
# N=1000: 0.47624 seconds
# N=3000: 0.46861 seconds
# N=5000: 0.4933 seconds
# N=7000: 0.57133 seconds
# N=10000: 0.77364 seconds
# N=30000: 1.85711 seconds
# N=100000: 5.9698 seconds

# %%
dmin = 1.0
dmax = 1E4
area = 1000

for N in [100, 300, 1000, 3000, 5000, 7000, 10000, 30000, 100000]:
    time0()
    ds = synth_fixed_N(
        N=N, dmin=dmin, pf=npf_new_loglog, n_steps=1
    )[0][0]
    for i in range(100):
        truncated_pareto_pdf(ds, dmin=1., dmax=1.05, n_points=1000)
    runtime('N=' + str(N))
# Out:
# N=100: 0.01281 seconds
# N=300: 0.01328 seconds
# N=1000: 0.01303 seconds
# N=3000: 0.013 seconds
# N=5000: 0.01341 seconds
# N=7000: 0.01372 seconds
# N=10000: 0.01441 seconds
# N=30000: 0.01885 seconds
# N=100000: 0.03907 seconds

# %%
0.5 * 1000 / 60
# Out:
# 8.333333333333334
